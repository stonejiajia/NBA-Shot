# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import *

import numpy as np

# %%
x = np.linspace(2, 2*np.pi, 2000)
y = np.sin(x)

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="74f3d3f6-8752-4e88-abec-96c014648216">Loading BokehJS ...</span>
#     </div>

# %%
source = ColumnDataSource(data=dict(x=x, y=y))
p = figure(title = "simple line example", plot_height = 300, plot_width = 600)
p.line(x, y, color = "#2222aa", line_width = 3, source = source, name = "foo")

# %%
def update(f, w=1, A=1, Phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan 
    source.data['y'] = A * func(w * x + Phi)
    source.push_notebook()

# %%
show(p)
# Out:
#     <div class="plotdiv" id="72edf701-07a6-4f4e-a39e-16016e3d18c7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("72edf701-07a6-4f4e-a39e-16016e3d18c7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '72edf701-07a6-4f4e-a39e-16016e3d18c7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5ebf6369-cbdb-4a20-9871-b9e5f6f2312d":{"roots":{"references":[{"attributes":{},"id":"e7b4da4d-2ee0-4f0e-a61c-f160bbadbb00","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2418376b-7634-41ec-917b-e6e09b65c38c","subtype":"Figure","type":"Plot"}},"id":"886bf28a-e5d3-4074-885b-3dde75913abb","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"58b7a968-176f-4c73-8254-093444a8b45a","type":"Line"},{"attributes":{"formatter":{"id":"b27fba78-5a39-4f92-a372-b34988c05fab","type":"BasicTickFormatter"},"plot":{"id":"2418376b-7634-41ec-917b-e6e09b65c38c","subtype":"Figure","type":"Plot"},"ticker":{"id":"514ead80-b791-444f-870a-92960c725a00","type":"BasicTicker"}},"id":"c729818e-ef66-4bf7-9f70-bde57a646abe","type":"LinearAxis"},{"attributes":{"plot":{"id":"2418376b-7634-41ec-917b-e6e09b65c38c","subtype":"Figure","type":"Plot"}},"id":"452393dd-e75e-4549-b05c-0ceae71869f1","type":"ResetTool"},{"attributes":{"plot":{"id":"2418376b-7634-41ec-917b-e6e09b65c38c","subtype":"Figure","type":"Plot"},"ticker":{"id":"dca43caa-ddd2-40ad-bb4a-931ff41889d4","type":"BasicTicker"}},"id":"48565e7f-a5aa-4e3d-9bbc-c0891292fe53","type":"Grid"},{"attributes":{"plot":{"id":"2418376b-7634-41ec-917b-e6e09b65c38c","subtype":"Figure","type":"Plot"}},"id":"7be8a8c5-37ee-43e4-b89e-fa83c4ce0881","type":"HelpTool"},{"attributes":{"plot":{"id":"2418376b-7634-41ec-917b-e6e09b65c38c","subtype":"Figure","type":"Plot"}},"id":"db1160ad-86d7-48bf-81b3-d762a5bb7194","type":"WheelZoomTool"},{"attributes":{},"id":"0157cc22-08f3-4598-8d58-f09ddbc4a261","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y","x","y","x"],"data":{"x":[2.0,2.0021426639855826,2.004285327971165,2.006427991956748,2.0085706559423304,2.010713319927913,2.0128559839134956,2.0149986478990782,2.017141311884661,2.0192839758702434,2.021426639855826,2.023569303841408,2.025711967826991,2.0278546318125734,2.029997295798156,2.0321399597837386,2.0342826237693212,2.036425287754904,2.0385679517404864,2.040710615726069,2.0428532797116516,2.0449959436972343,2.047138607682817,2.0492812716683995,2.051423935653982,2.0535665996395647,2.0557092636251473,2.05785192761073,2.0599945915963125,2.062137255581895,2.0642799195674777,2.0664225835530603,2.068565247538643,2.0707079115242255,2.0728505755098077,2.0749932394953903,2.077135903480973,2.0792785674665555,2.081421231452138,2.0835638954377207,2.0857065594233033,2.087849223408886,2.0899918873944685,2.092134551380051,2.0942772153656337,2.0964198793512163,2.098562543336799,2.1007052073223815,2.102847871307964,2.1049905352935467,2.1071331992791293,2.109275863264712,2.1114185272502946,2.113561191235877,2.1157038552214598,2.117846519207042,2.1199891831926245,2.122131847178207,2.1242745111637897,2.1264171751493723,2.128559839134955,2.1307025031205375,2.13284516710612,2.1349878310917028,2.1371304950772854,2.139273159062868,2.1414158230484506,2.143558487034033,2.145701151019616,2.1478438150051984,2.149986478990781,2.1521291429763636,2.154271806961946,2.156414470947529,2.1585571349331114,2.160699798918694,2.162842462904276,2.164985126889859,2.1671277908754414,2.169270454861024,2.1714131188466066,2.173555782832189,2.175698446817772,2.1778411108033544,2.179983774788937,2.1821264387745196,2.184269102760102,2.186411766745685,2.1885544307312674,2.19069709471685,2.1928397587024326,2.1949824226880152,2.197125086673598,2.1992677506591805,2.201410414644763,2.2035530786303457,2.2056957426159283,2.207838406601511,2.2099810705870935,2.2121237345726756,2.2142663985582582,2.216409062543841,2.2185517265294235,2.220694390515006,2.2228370545005887,2.2249797184861713,2.227122382471754,2.2292650464573365,2.231407710442919,2.2335503744285017,2.2356930384140843,2.237835702399667,2.2399783663852495,2.242121030370832,2.2442636943564147,2.2464063583419973,2.24854902232758,2.2506916863131625,2.252834350298745,2.2549770142843277,2.25711967826991,2.259262 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %%
from ipywidgets import interact
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,10), Phi=(0, 10, 0.1))
# Out:
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: BokehDeprecationWarning: bokeh.models.sources.push_notebook was deprecated in Bokeh 0.11.0; please use bokeh.io.push_notebook instead
# <function __main__.update>

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.stocks import AAPL

# prepare some data
aapl = np.array(AAPL['adj_close'])
aapl_dates = np.array(AAPL['date'], dtype=np.datetime64)

window_size = 30
window = np.ones(window_size)/float(window_size)
aapl_avg = np.convolve(aapl, window, 'same')

# output to static HTML file
output_file("stocks.html", title="stocks.py example")

# create a new plot with a a datetime axis type
p = figure(width=800, height=350, x_axis_type="datetime")

# add renderers
p.circle(aapl_dates, aapl, size=4, color='darkgrey', alpha=0.2, legend='close')
p.line(aapl_dates, aapl_avg, color='navy', legend='avg')

# NEW: customize by setting attributes
p.title = "AAPL One-Month Average"
p.legend.location = "top_left"
p.grid.grid_line_alpha=0
p.xaxis.axis_label = 'Date'
p.yaxis.axis_label = 'Price'
p.ygrid.band_fill_color="olive"
p.ygrid.band_fill_alpha = 0.1

# show the results
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-9d22c4a9e7b8> in <module>()
#       2
#       3 from bokeh.plotting import figure, output_file, show
# ----> 4 from bokeh.sampledata.stocks import AAPL
#       5
#       6 # prepare some data
#
# /Users/stone20091652/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/bokeh/sampledata/stocks.py in <module>()
#      44     return data
#      45
# ---> 46 data_dir = _data_dir()
#      47
#      48 stocks = [
#
# /Users/stone20091652/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/bokeh/sampledata/__init__.py in _data_dir(file_name, create)
#      35     if not exists(data_dir):
#      36         if not create:
# ---> 37             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#      38         print("Creating %s directory" % data_dir)
#      39         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()

# %%
from bokeh.plotting import figure, show

# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
output_file("log_lines.html")

# create a new plot
p = figure(
   tools="pan,box_zoom,reset,save",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#         var all_models = [{"id": "a30b9fbf-677f-400c-a65e-0fc3116cbd77", "type": "LinearAxis", "attributes": {"ticker": {"id": "cf70d745-d585-4e42-9464-feb35d85197a", "type": "BasicTicker"}, "formatter": {"id": "78123ed8-b4df-4ebb-b1fa-d0f4b142e7a5", "type": "BasicTickFormatter"}, "id": "a30b9fbf-677f-400c-a65e-0fc3116cbd77", "tags": [], "axis_label": "sections", "doc": null, "plot": {"id": "5b3ee15a-5ded-40c9-8f22-f321ef0ef3f0", "type": "Plot", "subtype": "Figure"}}}, {"id": "26f48bce-68d2-469b-ad97-b74e748f6439", "type": "ColumnDataSource", "attributes": {"selected": {"1d": {"indices": []}, "0d": {"indices": [], "flag": false}, "2d": {"indices": []}}, "column_names": ["y", "x"], "tags": [], "id": "26f48bce-68d2-469b-ad97-b74e748f6439", "callback": null, "doc": null, "data": {"y": [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0], "x": [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]}}}, {"id": "16728663-629b-49d6-acf3-2d8007108975", "type": "PanTool", "attributes": {"dimensions": ["width", "height"], "tags": [], "id": "16728663-629b-49d6-acf3-2d8007108975", "doc": null, "plot": {"id": "5b3ee15a-5ded-40c9-8f22-f321ef0ef3f0", "type": "Plot", "subtype": "Figure"}}}, {"id": "5a9316e4-ddad-4d38-a18d-dbd5a63d0813", "type": "PreviewSaveTool", "attributes": {"tags": [], "id": "5a9316e4-ddad-4d38-a18d-dbd5a63d0813", "doc": null, "plot": {"id": "5b3ee15a-5ded-40c9-8f22-f321ef0ef3f0", "type": "Plot", "subtype": "Figure"}}}, {"id": "fda37789-1adc-469f-a1b8-12cc2079bbd6", "type": "Grid", "attributes": {"ticker": {"id": "cf70d745-d585-4e42-9464-feb35d85197a", "type": "BasicTicker"}, "tags": [], "id": "fda37789-1adc-469f-a1b8-12cc2079bbd6", "dimension": 0, "doc": null, "plot": {"id": "5b3ee15a-5ded-40c9-8f22-f321ef0ef3f0", "type": "Plot", "subtype": "Figure"}}}, {"id": "36c83a79-198f-454d-a4bf-429679c2cf29", "type": "BoxZoomTool", "attributes": {"dimensions": ["width", "height"], "tags": [], "id": "36c83a79-198f-454d-a4bf-429679c2cf29", "doc": null, "plot": {"id": "5b3ee15a-5ded-40c9-8f22-f321ef0ef3f0", "type": "Plot", "subtype": "Figure"}}}, {"id": "189c5f7f-32e1-4b7a-8de7-152d5f2ad914", "type": "Circle", "attributes": {"doc": null, "tags": [], "line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_alpha": {"value": 0.1}, "size": {"units": "screen", "value": 6}, "fill_color": {"value": "#1f77b4"}, "id": "189c5f7f-32e1-4b7a-8de7-152d5f2ad914", "y": {"field": "y"}, "x": {"field": "x"}}}, {"id": "9f2e1365-9a3b-4ef3-b0e2-5f617d1b9dca", "type": "ColumnDataSource", "attributes": {"selected": {"1d": {"indices": []}, "0d": {"indices": [], "flag": false}, "2d": {"indices": []}}, "column_names": ["y", "x"], "tags": [], "id": "9f2e1365-9a3b-4ef3-b0e2-5f617d1b9dca", "callback": null, "doc": null, "data": {"y": [1.023292992280754, 1.7782794100389228, 10.0, 177.82794100389228, 10000.0, 1778279.410038923, 1000000000.0], "x": [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]}}}, {"id": "d753d5bb-8a43-4b7f-b917-738309607a28", "type": "GlyphRenderer", "attributes": {"data_source": {"id": "fde9a07d-4678-4a78-a513-d8f390806838", "type": "ColumnDataSource"}, "nonselection_glyph": {"id": "44e4ba6b-60b5-4f20-98f2-9566acbcebca", "type": "Line"}, "id": "d753d5bb-8a43-4b7f-b917-738309607a28", "tags": [], "selection_glyph": null, "doc": null, "glyph": {"id": "148166b2-6bf3-44e5-9f30-fa7fa0f83993", "type": "Line"}}}, {"id": "e9e541ac-2177-4bd9-8e5c-8658c630da40", "type": "ColumnDataSource", "attributes": {"selected": {"1d": {"indices": []}, "0d": {"indices": [], "flag": false}, "2d": {"indices": []}}, "column_names": ["y", "x"], "tags": [], "id": "e9e541ac-2177-4bd9-8e5c-8658c630da40", "callback": null, "doc": null, "data": {"y": [1.2589254117941673, 3.1622776601683795, 10.0, 31.622776601683793, 100.0, 316.22776601683796, 1000.0], "x": [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]}}}, {"id": "cf70d745-d585-4e42-9464-feb35d85197a", "type": "BasicTicker", "attributes": {"mantissas": [2, 5, 10], "tags": [], "id": "cf70d745-d585-4e42-9464-feb35d85197a", "num_minor_ticks": 5, "doc": null}}, {"id": "2a7e1 ...

# %%
import numpy as np
from bokeh.plotting import *

# prepare some data
N = 100
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)
y2 = np.sin(x) + np.cos(x)

# output to static HTML file
output_file("linked_panning.html")

# create a new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# NEW: create a new plot and share both ranges
s2 = figure(width=250, height=250, x_range=s1.x_range, y_range=s1.y_range, title=None)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# NEW: create a new plot and share only one range
s3 = figure(width=250, height=250, x_range=s1.x_range, title=None)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# NEW: put the subplots in a gridplot
p = gridplot([[s1, s2, s3]], toolbar_location=None)

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="833656ca-837a-4ea7-80d9-cf3e3cccc649"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("833656ca-837a-4ea7-80d9-cf3e3cccc649");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '833656ca-837a-4ea7-80d9-cf3e3cccc649' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9774dfe3-0051-4a1c-a5c9-0dd2477697df":{"roots":{"references":[{"attributes":{},"id":"7019d702-19be-4680-8ad8-14edddcb3460","type":"BasicTicker"},{"attributes":{"plot":{"id":"103e7c5b-2428-4e73-94dc-4b78a2871bd7","subtype":"Figure","type":"Plot"},"ticker":{"id":"4494d0e1-f0fd-4275-be38-013d6f3c12dd","type":"BasicTicker"}},"id":"867f742c-2c32-4ddd-a2d5-4f3f2fcdf822","type":"Grid"},{"attributes":{},"id":"f37f953e-33d2-4a9f-be50-e6f85322e9bd","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2f91a6f7-0854-40e9-9da8-88e4c8e54fdc","type":"Line"},{"attributes":{},"id":"689312f2-7e92-4df3-b748-dab674845c7b","type":"ToolEvents"},{"attributes":{"below":[{"id":"fadabdea-b805-43d8-9b20-b8e6bf9a9590","type":"LinearAxis"}],"left":[{"id":"2dfd2655-5b72-4aee-91db-9e73fc1c298e","type":"LinearAxis"}],"plot_height":250,"plot_width":250,"renderers":[{"id":"fadabdea-b805-43d8-9b20-b8e6bf9a9590","type":"LinearAxis"},{"id":"c8170680-0001-49da-8103-17599fbd0b56","type":"Grid"},{"id":"2dfd2655-5b72-4aee-91db-9e73fc1c298e","type":"LinearAxis"},{"id":"b3cfc4c4-30a0-41e8-8a7c-3735940f27d5","type":"Grid"},{"id":"204c9420-f93a-426d-b557-fcaa245ec7a5","type":"BoxAnnotation"},{"id":"1acb5f29-0753-4735-9b7c-e71d426686ba","type":"GlyphRenderer"}],"title":null,"tool_events":{"id":"fb2e035c-f8ca-4057-9e8e-f354cd3d1cff","type":"ToolEvents"},"tools":[{"id":"8278eacb-31f6-40a2-9e38-ff18f5fb34f6","type":"PanTool"},{"id":"ff50e361-475b-4c1a-8688-377be2673a6e","type":"WheelZoomTool"},{"id":"203d9c93-8cd9-4e70-992c-7f94ac50a9b0","type":"BoxZoomTool"},{"id":"38b55299-efa5-429a-83b8-9d6bec716883","type":"PreviewSaveTool"},{"id":"97876469-6bfa-4bb0-a69e-63b088496e47","type":"ResizeTool"},{"id":"3e1190ac-dceb-470f-b6b2-2f83f841d308","type":"ResetTool"},{"id":"20deeaec-30ea-48c9-b70c-28b1818b9cdb","type":"HelpTool"}],"x_range":{"id":"3a822fa9-77ea-4c1a-9366-8722b00b9ac4","type":"DataRange1d"},"y_range":{"id":"57794126-9267-4de0-a4f3-afb44fb91f4f","type":"DataRange1d"}},"id":"7a3e6cb6-84a5-46a9-b56b-9f6adf60d30c","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6861f96-4b42-47ac-8c7a-9dcd3bc3d3ad","type":"Circle"},{"attributes":{"plot":{"id":"103e7c5b-2428-4e73-94dc-4b78a2871bd7","subtype":"Figure","type":"Plot"}},"id":"a7d63d99-f43c-42ee-a9aa-8d1ccc85aecf","type":"ResetTool"},{"attributes":{"children":[[{"id":"c9ba0993-3430-448a-8c22-ece571c2565c","subtype":"Figure","type":"Plot"},{"id":"7a3e6cb6-84a5-46a9-b56b-9f6adf60d30c","subtype":"Figure","type":"Plot"},{"id":"103e7c5b-2428-4e73-94dc-4b78a2871bd7","subtype":"Figure","type":"Plot"}]],"toolbar_location":null},"id":"64242db3-98a1-4dd7-81ef-040bd792010b","type":"GridPlot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.1,0.5,1.0,1.5,2.0,2.5,3.0],"y":[0.010000000000000002,0.25,1.0,2.25,4.0,6.25,9.0]}},"id":"bd5da25d-8838-42ec-9d3a-b7dba483f610","type":"ColumnDataSource"},{"attributes":{"axis_label":"particles","formatter":{"id":"d222af4a-da83-4ccb-bb0a-1775552d3f7f","type":"LogTickFormatter"},"plot":{"id":"425773e9-de77-4194-957f-d67f37b5421b","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e21a8f-fb11-4d0e-bacc-4f749108523d","type":"LogTicker"}},"id":"f8621c28-ab4e-4ba9-9bd0-29516ce81bfe","type":"LogAxis"},{"attributes":{"axis_label":"particles","formatter":{"id":"13c68d71-374b-4866-8e8e-845d8b1e5f3c","type":"LogTickFormatter"},"plot":{"id":"6faa7edd-307a-44fb-a6b5-e7db62be1a54","subtype":"Figure","type":"Plot"},"ticker":{"id":"e9981a54-4538-48db-832e-a15744e71ca8","type":"LogTicker"}},"id":"61994faa-ea2b-4ace-bbf3-94822823c061","type":"LogAxis"},{"attributes":{"data_source":{"id":"bdd0640f-451c-47b2-988e-cdcc93813c09","type":"ColumnDataSource"},"glyph":{"id":"f8f364fd-5ce9-46c4-b1 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.stocks import AAPL

# prepare some data
aapl = np.array(AAPL['adj_close'])
aapl_dates = np.array(AAPL['date'], dtype=np.datetime64)

window_size = 30
window = np.ones(window_size)/float(window_size)
aapl_avg = np.convolve(aapl, window, 'same')

# output to static HTML file
output_file("stocks.html", title="stocks.py example")

# create a new plot with a a datetime axis type
p = figure(width=800, height=350, x_axis_type="datetime")

# add renderers
p.circle(aapl_dates, aapl, size=4, color='darkgrey', alpha=0.2, legend='close')
p.line(aapl_dates, aapl_avg, color='navy', legend='avg')

# NEW: customize by setting attributes
p.title = "AAPL One-Month Average"
p.legend.location = "top_left"
p.grid.grid_line_alpha=0
p.xaxis.axis_label = 'Date'
p.yaxis.axis_label = 'Price'
p.ygrid.band_fill_color="olive"
p.ygrid.band_fill_alpha = 0.1

# show the results
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-9d22c4a9e7b8> in <module>()
#       2
#       3 from bokeh.plotting import figure, output_file, show
# ----> 4 from bokeh.sampledata.stocks import AAPL
#       5
#       6 # prepare some data
#
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/bokeh/sampledata/stocks.py in <module>()
#      44     return data
#      45
# ---> 46 data_dir = _data_dir()
#      47
#      48 stocks = [
#
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/bokeh/sampledata/__init__.pyc in _data_dir(file_name, create)
#      35     if not exists(data_dir):
#      36         if not create:
# ---> 37             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#      38         print("Creating %s directory" % data_dir)
#      39         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()

# %%
from ipywidgets import Controller

# %%
from ipywidgets import interact

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# /Users/stone20091652/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from ipywidgets import interactive
from IPython.display import Audio, display
import numpy as np

# %%
def beat_freq(f1=220.0, f2=224.0):
    max_time = 3
    rate = 8000
    times = np.linspace(0,max_time,rate*max_time)
    signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)
    print(f1, f2, abs(f1-f2))
    display(Audio(data=signal, rate=rate))
    return signal

# %%
v = interactive(beat_freq, f1=(200.0,300.0), f2=(200.0,300.0))
display(v)
# Out:
# (220.0, 224.0, 4.0)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([  0.00000000e+00,   3.46966469e-01,   6.83408155e-01, ...,
#         -6.83408155e-01,  -3.46966469e-01,   3.84296828e-13])

# %%
v.kwargs
# Out:
# {'f1': 220.0, 'f2': 224.0}

# %%
f1, f2 = v.children
f1.value = 255
f2.value = 260
plt.plot(v.result[0:6000])
# Out:
# (255.0, 260.0, 5.0)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# array([  0.00000000e+00,   4.01744148e-01,   7.87106566e-01, ...,
#         -7.87106566e-01,  -4.01744148e-01,  -7.97636075e-13])

# %% [markdown]
# #  Using Game Controllers in the Jupyter Notebook

# %%
from ipywidgets import Controller

# %%
Controller()
# Out:
# Widget Javascript not detected.  It may not be installed properly.

# %%
Controller(index=1)
# Out:
# Widget Javascript not detected.  It may not be installed properly.

# %% [markdown]
# # Custom Widget - Hello World

# %%
from __future__ import print_function # For py 2.7 compat

# %%
import ipywidgets as widgets
from traitlets import Unicode


class HelloWidget(widgets.DOMWidget):
    _view_name = Unicode('HelloView').tag(sync=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-24f00d82fca8> in <module>()
#       3
#       4
# ----> 5 class HelloWidget(widgets.DOMWidget):
#       6     _view_name = Unicode('HelloView').tag(sync=True)
#
# <ipython-input-11-24f00d82fca8> in HelloWidget()
#       4
#       5 class HelloWidget(widgets.DOMWidget):
# ----> 6     _view_name = Unicode('HelloView').tag(sync=True)
#
# AttributeError: 'Unicode' object has no attribute 'tag'

# %%
# %%javascript
# require(["jupyter-js-widgets"], function(widgets) {
#
# });

# %%
# %%javascript
# require(["jupyter-js-widgets"], function(widgets) {
#
#     // Define the HelloView
#     var HelloView = widgets.DOMWidgetView.extend({
#
#     });
#
#     // Register the HelloView with the widget manager.
#     widgets.ManagerBase.register_widget_view('HelloView', HelloView);
# });

# %%
# %%javascript
# require(["jupyter-js-widgets"], function(widgets) {
#
#     var HelloView = widgets.DOMWidgetView.extend({
#
#         // Render the view.
#         render: function() {
#             this.$el.text('Hello World!');
#         },
#     });
#
#     widgets.ManagerBase.register_widget_view('HelloView', HelloView);
# });

# %%
HelloWidget()
# Out:
# Widget Javascript not detected.  It may not be installed properly.

# %% [markdown]
# # Data Picker Widget

# %%
from __future__ import print_function # For py 2.7 compat

import ipywidgets as widgets # Widget definitions
from IPython.display import display # Used to display widgets in the notebook
from traitlets import Unicode # Used to declare attributes of our widget

# %%
class DateWidget(widgets.DOMWidget):
    _view_name = Unicode('DatePickerView').tag(sync=True)

# %%
class DateWidget(widgets.DOMWidget):
    _view_name = Unicode('DatePickerView').tag(sync=True)

# %%
# %%javascript
#
# require(["jupyter-js-widgets"], function(widgets) {
#
#     // Define the DatePickerView
#     var DatePickerView = widgets.DOMWidgetView.extend({
#         render: function() { this.$el.text('Hello World!'); },
#     });
#
#     // Register the DatePickerView with the widget manager.
#     widgets.ManagerBase.register_widget_view('DatePickerView', DatePickerView);
# });

# %%
DateWidget()
# Out:
# Widget Javascript not detected.  It may not be installed properly.

# %%
from dateutil import parser

# %%
class DateWidget(widgets.DOMWidget):
    _view_name = Unicode('DatePickerView').tag(sync=True)
    value = Unicode().tag(sync=True)
    description = Unicode().tag(sync=True)

# %%
class DateWidget(widgets.DOMWidget):
    _view_name = Unicode('DatePickerView').tag(sync=True)
    value = Unicode().tag(sync=True)
    description = Unicode().tag(sync=True)

    # This function automatically gets called by the traitlet machinery when
    # value is modified because of this function's name.
    def _value_changed(self, name, old_value, new_value):
        pass

# %%
class DateWidget(widgets.DOMWidget):
    _view_name = Unicode('DatePickerView').tag(sync=True)
    value = Unicode().tag(sync=True)
    description = Unicode().tag(sync=True)
    
    # This function automatically gets called by the traitlet machinery when
    # value is modified because of this function's name.
    def _value_changed(self, name, old_value, new_value):
        
        # Parse the date time value.
        try:
            parsed_date = parser.parse(new_value)
            parsed_date_string = parsed_date.strftime("%Y-%m-%d")
        except:
            parsed_date_string = ''
        
        # Set the parsed date string if the current date string is different.
        if self.value != parsed_date_string:
            self.value = parsed_date_string

# %%
class DateWidget(widgets.DOMWidget):
    _view_name = Unicode('DatePickerView').tag(sync=True)
    value = Unicode().tag(sync=True)
    description = Unicode().tag(sync=True)
    
    def __init__(self, **kwargs):
        super(DateWidget, self).__init__(**kwargs)
        
        self.validate = widgets.CallbackDispatcher()
    
    # This function automatically gets called by the traitlet machinery when
    # value is modified because of this function's name.
    def _value_changed(self, name, old_value, new_value):
        
        # Parse the date time value.
        try:
            parsed_date = parser.parse(new_value)
            parsed_date_string = parsed_date.strftime("%Y-%m-%d")
        except:
            parsed_date_string = ''
        
        # Set the parsed date string if the current date string is different.
        if old_value != new_value:
            valid = self.validate(parsed_date)
            if valid in (None, True):
                self.value = parsed_date_string
            else:
                self.value = old_value
                self.send_state() # The traitlet event won't fire since the value isn't changing.
                                  # We need to force the back-end to send the front-end the state
                                  # to make sure that the date control date doesn't change.

# %%
# %%javascript
#
# require(["jupyter-js-widgets"], function(widgets) {
#
#     // Define the DatePickerView
#     var DatePickerView = widgets.DOMWidgetView.extend({
#         render: function() {
#             this.$el.addClass('widget-hbox-single'); /* Apply this class to the widget container to make
#                                                         it fit with the other built in widgets.*/
#             // Create a label.
#             this.$label = $('<div />')
#                 .addClass('widget-hlabel')
#                 .appendTo(this.$el)
#                 .hide(); // Hide the label by default.
#
#             // Create the date picker control.
#             this.$date = $('<input />')
#                 .attr('type', 'date')
#                 .appendTo(this.$el);
#         },
#
#         update: function() {
#
#             // Set the value of the date control and then call base.
#             this.$date.val(this.model.get('value')); // ISO format "YYYY-MM-DDTHH:mm:ss.sssZ" is required
#
#             // Hide or show the label depending on the existance of a description.
#             var description = this.model.get('description');
#             if (description == undefined || description == '') {
#                 this.$label.hide();
#             } else {
#                 this.$label.show();
#                 this.$label.text(description);
#             }
#
#             return DatePickerView.__super__.update.apply(this);
#         },
#
#         // Tell Backbone to listen to the change event of input controls (which the HTML date picker is)
#         events: {"change": "handle_date_change"},
#
#         // Callback for when the date is changed.
#         handle_date_change: function(event) {
#             this.model.set('value', this.$date.val());
#             this.touch();
#         },
#     });
#
#     // Register the DatePickerView with the widget manager.
#     widgets.ManagerBase.register_widget_view('DatePickerView', DatePickerView);
# });

# %%
# Add some additional widgets for aesthetic purpose
display(widgets.Text(description="First:"))
display(widgets.Text(description="Last:"))

my_widget = DateWidget()
display(my_widget)
my_widget.description="DOB:"
# Out:
# Widget Javascript not detected.  It may not be installed properly.
# Widget Javascript not detected.  It may not be installed properly.
# Widget Javascript not detected.  It may not be installed properly.

# %% [markdown]
# # Exploring Graphs

# %%
from ipywidgets import interact

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import networkx as nx

# %%
# wrap a few graph generation functions so they have the same signature

def random_lobster(n, m, k, p):
    return nx.random_lobster(n, p, p / m)

def powerlaw_cluster(n, m, k, p):
    return nx.powerlaw_cluster_graph(n, m, p)

def erdos_renyi(n, m, k, p):
    return nx.erdos_renyi_graph(n, p)

def newman_watts_strogatz(n, m, k, p):
    return nx.newman_watts_strogatz_graph(n, k, p)

def plot_random_graph(n, m, k, p, generator):
    g = generator(n, m, k, p)
    nx.draw(g)
    plt.show()

# %%
interact(plot_random_graph, n=(2,30), m=(1,10), k=(1,10), p=(0.0, 1.0, 0.001),
        generator={'lobster': random_lobster,
                   'power law': powerlaw_cluster,
                   'Newman-Watts-Strogatz': newman_watts_strogatz,
                   u'Erdős-Rényi': erdos_renyi,
                   });

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-9d22c4a9e7b8> in <module>()
#       2
#       3 from bokeh.plotting import figure, output_file, show
# ----> 4 from bokeh.sampledata.stocks import AAPL
#       5
#       6 # prepare some data
#
# /Users/stone20091652/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/bokeh/sampledata/stocks.py in <module>()
#      44     return data
#      45
# ---> 46 data_dir = _data_dir()
#      47
#      48 stocks = [
#
# /Users/stone20091652/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/bokeh/sampledata/__init__.py in _data_dir(file_name, create)
#      35     if not exists(data_dir):
#      36         if not create:
# ---> 37             raise RuntimeError('bokeh sample data directory does not exist, please execute bokeh.sampledata.download()')
#      38         print("Creating %s directory" % data_dir)
#      39         try:
#
# RuntimeError: bokeh sample data directory does not exist, please execute bokeh.sampledata.download()
